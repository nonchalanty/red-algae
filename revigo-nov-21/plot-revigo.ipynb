# %% [markdown]
# # Imports and configuration

# %%
import altair as alt
import pandas as pd
import plotly.express as px

from pathlib import Path

# %% [markdown]
# ## Sample Diagram
# The following is an example of the single category of Cellular Component, as extracted from a manual rerun of REViGO.

# %%
data = [
    ["GO:0005874","microtubule", 0.590923058896654, -4.00372136407618, 3.93380303408685, 5.07433362293908, 0.743307611944267, 0],
    ["GO:0042555","MCM complex",0.0516392267501353,5.29409032883786,-0.438484234906433,4.01582063426207,0.736867388621876,0],
    ["GO:0005886","plasma membrane",15.5064680247866,-2.59930578712986,-4.79438349762051,6.49331205332051,0.980465972776413,4.124E-05],
    ["GO:0030173","integral component of Golgi membrane",0.0482779463204013,-0.0820996416106789,6.61844221537962,3.98659260682221,0.720783016873817,0.16417986],
    ["GO:0031083","BLOC-1 complex",0.0157955281823943,6.03044083325888,2.61728943021364,3.50147007210041,0.638408624494431,0.22740185],
    ["GO:0030532","small nuclear ribonucleoprotein complex",0.138166054523554,2.1939043417736,2.03060434260059,4.44321603416583,0.571526896999077,0.2622474],
    ["GO:0008250","oligosaccharyltransferase complex",0.0394539627330108,2.22238070210506,4.52148800747906,3.89894446686651,0.602647357590838,0.39260902]
]

columns = ["term_ID","description","frequency","plot_X","plot_Y","log_size","uniqueness","dispensability"]

df = pd.DataFrame(data, columns=columns)
df.head()
# Out:
#       term_ID                           description  frequency    plot_X  \
# 0  GO:0005874                           microtubule   0.590923 -4.003721
# 1  GO:0042555                           MCM complex   0.051639  5.294090
# 2  GO:0005886                       plasma membrane  15.506468 -2.599306
# 3  GO:0030173  integral component of Golgi membrane   0.048278 -0.082100
# 4  GO:0031083                        BLOC-1 complex   0.015796  6.030441
#
#      plot_Y  log_size  uniqueness  dispensability
# 0  3.933803  5.074334    0.743308        0.000000
# 1 -0.438484  4.015821    0.736867        0.000000
# 2 -4.794383  6.493312    0.980466        0.000041
# 3  6.618442  3.986593    0.720783        0.164180
# 4  2.617289  3.501470    0.638409        0.227402

# %%
base = alt.Chart(df).mark_point(filled=True, fillOpacity=0.5).encode(
    y=alt.Y('plot_Y', title="Semantic Space Y"),
    x=alt.X('plot_X', title="Semantic Space X"),
    size=alt.Size('log_size', scale=alt.Scale(base=0, domain=[3.5,6], range=[1000, 7000])),
    color=alt.Color('uniqueness', scale=alt.Scale(scheme='viridis')),
    tooltip=["term_ID", "description", "frequency", "log_size", "uniqueness", "dispensability"]
)

text = alt.Chart(df).mark_text(
#     align='left',
#     baseline='middle',
#     dx=7
).encode(
    y=alt.Y('plot_Y', title="Semantic Space Y"),
    x=alt.X('plot_X', title="Semantic Space X"),
    color=alt.Color('uniqueness', scale=alt.Scale(scheme='viridis')),
    text="description"
)

(base + text).properties(
    title="REViGO plot of top non-redundant GO terms for K. alvarezii protein predictions",
    height=600,
    width=800
).interactive()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # All output data from complete REViGO run

# %%
# Parse results
stringent_results = "Revigo_Result.txt"
all_results = {
    "MF": "RevigoMF.csv",
    "BP": "RevigoBP.csv",
    "CC": "RevigoCC.csv"
}
ontologies = {
    "MF": "Molecular function",
    "CC": "Cellular component",
    "BP": "Biological process"
}

for category, f in all_results.items():
    if not Path(f).exists():
        print(f"No file exists for {f}. \nPlease export CSV data from http://revigo.irb.hr/Results.aspx.")
        

all_dfs = []
for category, f in all_results.items():         
    df = pd.read_csv(f, sep=",", skipinitialspace = True, quotechar='"')
    df["Subontology symbol"] = category
    df["Subontology"] = ontologies[category]
    all_dfs.append(df)

master_df = pd.concat(all_dfs)
master_df.head() # 634 rows before filtering to Gabriels
# Out:
#        TermID                               Name  Frequency     PlotX  \
# 0  GO:0003777         microtubule motor activity   0.186775 -1.277958
# 1  GO:0009976        tocopherol cyclase activity   0.002332  4.078306
# 2  GO:0003963  RNA-3'-phosphate cyclase activity   0.005404       NaN
# 3  GO:0003911         DNA ligase (NAD+) activity   0.030633       NaN
# 4  GO:0003910          DNA ligase (ATP) activity   0.053418       NaN
#
#       PlotY   LogSize  Value  Uniqueness  Dispensability  Representative  \
# 0 -1.163526  4.741884    NaN    0.980471        0.000000             NaN
# 1  7.417087  2.838849    NaN    0.966660        0.000000             NaN
# 2       NaN  3.203577    NaN    0.862812        0.704210          9976.0
# 3       NaN  3.956793    NaN    0.826803        0.744027          9976.0
# 4       NaN  4.198272    NaN    0.820893        0.904895          9976.0
#
#    Eliminated Subontology symbol         Subontology
# 0       False                 MF  Molecular function
# 1       False                 MF  Molecular function
# 2        True                 MF  Molecular function
# 3        True                 MF  Molecular function
# 4        True                 MF  Molecular function

# %%
# Plot graphs for each category of GO term
base = alt.Chart().mark_point(filled=True, fillOpacity=0.5).encode(
    y=alt.Y('PlotY', title="Semantic Space Y"),
    x=alt.X('PlotX', title="Semantic Space X"),
    size=alt.Size('LogSize', scale=alt.Scale(base=0, domain=[3.5,6], range=[1000, 7000])),
    color=alt.Color('Uniqueness', scale=alt.Scale(scheme='viridis')),
    tooltip=["TermID", "Name", "Frequency", "LogSize", "Uniqueness", "Dispensability"]
)

text = alt.Chart().mark_text().encode(
    y=alt.Y('PlotY', title="Semantic Space Y"),
    x=alt.X('PlotX', title="Semantic Space X"),
    color=alt.Color('Uniqueness', scale=alt.Scale(scheme='viridis')),
    text="Name"
)

plot = alt.layer(base, text, data=master_df).facet(
    row='Subontology:O'
).interactive()

# %%
plot
# Out:
# alt.FacetChart(...)

# %%
# Plot graphs for each category of GO term separately
category = "Molecular function"
df = master_df[master_df["Subontology"] == category]

base = alt.Chart(df).mark_point(filled=True, fillOpacity=0.5).encode(
    y=alt.Y('PlotY', title="Semantic Space Y"),
    x=alt.X('PlotX', title="Semantic Space X"),
    size=alt.Size('LogSize', scale=alt.Scale(base=0, domain=[3.5,6], range=[1000, 7000])),
    color=alt.Color('Uniqueness', scale=alt.Scale(scheme='viridis')),
    tooltip=["TermID", "Name", "Frequency", "LogSize", "Uniqueness", "Dispensability"]
)

text = alt.Chart(df).mark_text().encode(
    y=alt.Y('PlotY', title="Semantic Space Y"),
    x=alt.X('PlotX', title="Semantic Space X"),
    color=alt.Color('Uniqueness', scale=alt.Scale(scheme='viridis')),
    text="Name"
)

plot = alt.layer(base, text).properties(
    title=f"REViGO plot of top non-redundant '{category}' GO terms for K. alvarezii protein predictions",
    height=600,
    width=800
).interactive()

plot
# Out:
# alt.LayerChart(...)

# %%
# Plot graphs for each category of GO term separately
category = "Cellular component"
df = master_df[master_df["Subontology"] == category]

base = alt.Chart(df).mark_point(filled=True, fillOpacity=0.5).encode(
    y=alt.Y('PlotY', title="Semantic Space Y"),
    x=alt.X('PlotX', title="Semantic Space X"),
    size=alt.Size('LogSize', scale=alt.Scale(base=0, domain=[3.5,6], range=[1000, 7000])),
    color=alt.Color('Uniqueness', scale=alt.Scale(scheme='viridis')),
    tooltip=["TermID", "Name", "Frequency", "LogSize", "Uniqueness", "Dispensability"]
)

text = alt.Chart(df).mark_text().encode(
    y=alt.Y('PlotY', title="Semantic Space Y"),
    x=alt.X('PlotX', title="Semantic Space X"),
    color=alt.Color('Uniqueness', scale=alt.Scale(scheme='viridis')),
    text="Name"
)

plot = alt.layer(base, text).properties(
    title=f"REViGO plot of top non-redundant '{category}' GO terms for K. alvarezii protein predictions",
    height=600,
    width=800
).interactive()

plot
# Out:
# alt.LayerChart(...)

# %%
# Plot graphs for each category of GO term separately
category = "Biological process"
df = master_df[master_df["Subontology"] == category]

base = alt.Chart(df).mark_point(filled=True, fillOpacity=0.5).encode(
    y=alt.Y('PlotY', title="Semantic Space Y"),
    x=alt.X('PlotX', title="Semantic Space X"),
    size=alt.Size('LogSize', scale=alt.Scale(base=0, domain=[3.5,6], range=[1000, 7000])),
    color=alt.Color('Uniqueness', scale=alt.Scale(scheme='viridis')),
    tooltip=["TermID", "Name", "Frequency", "LogSize", "Uniqueness", "Dispensability"]
)

text = alt.Chart(df).mark_text().encode(
    y=alt.Y('PlotY', title="Semantic Space Y"),
    x=alt.X('PlotX', title="Semantic Space X"),
    color=alt.Color('Uniqueness', scale=alt.Scale(scheme='viridis')),
    text="Name"
)

plot = alt.layer(base, text).properties(
    title=f"REViGO plot of top non-redundant '{category}' GO terms for K. alvarezii protein predictions",
    height=600,
    width=800
).interactive()

plot
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Filtered output data from stringent REViGO run

# %%
# Parse stringent results from Gabriel's list
filter_df = pd.read_csv(stringent_results, sep="\t")
filter_df.rename({"Subontoloy": "Subontology"}, axis=1, inplace=True)
filter_df.head()  # 192 rows in white list

# Filter original results using this whitelist
master_df = master_df[master_df["TermID"].isin(list(filter_df["TermID"]))]
master_df.head() # 192 rows after filtering
# Out:
#         TermID                                    Name  Frequency     PlotX  \
# 0   GO:0003777              microtubule motor activity   0.186775 -1.277958
# 1   GO:0009976             tocopherol cyclase activity   0.002332  4.078306
# 5   GO:0016531               copper chaperone activity   0.008897  3.567694
# 9   GO:0017056  structural constituent of nuclear pore   0.065780 -5.369610
# 10  GO:0042030               ATPase inhibitor activity   0.016437 -1.858998
#
#        PlotY   LogSize  Value  Uniqueness  Dispensability  Representative  \
# 0  -1.163526  4.741884    NaN    0.980471             0.0             NaN
# 1   7.417087  2.838849    NaN    0.966660             0.0             NaN
# 5   7.249564  3.419956    NaN    0.993093             0.0             NaN
# 9  -1.436137  4.288674    NaN    0.967328             0.0             NaN
# 10  0.421116  3.686458    NaN    0.982641             0.0             NaN
#
#     Eliminated Subontology symbol         Subontology
# 0        False                 MF  Molecular function
# 1        False                 MF  Molecular function
# 5        False                 MF  Molecular function
# 9        False                 MF  Molecular function
# 10       False                 MF  Molecular function

# %%
# Plot graphs for each category of GO term separately
plots = []
for category in master_df["Subontology"].unique():
    df = master_df[master_df["Subontology"] == category]
    domain = [df["LogSize"].min(), df["LogSize"].max()]

    base = alt.Chart(df).mark_point(filled=True, fillOpacity=0.5).encode(
        y=alt.Y('PlotY', title="Semantic Space Y"),
        x=alt.X('PlotX', title="Semantic Space X"),
        size=alt.Size('LogSize', scale=alt.Scale(base=0, domain=domain, range=[1000, 7000])),
        color=alt.Color('Uniqueness', scale=alt.Scale(scheme='viridis')),
        tooltip=["TermID", "Name", "Frequency", "LogSize", "Uniqueness", "Dispensability"]
    )

    text = alt.Chart(df).mark_text().encode(
        y=alt.Y('PlotY', title="Semantic Space Y"),
        x=alt.X('PlotX', title="Semantic Space X"),
        color=alt.Color('Uniqueness', scale=alt.Scale(scheme='viridis')),
        text="Name"
    )

    plot = alt.layer(base, text).properties(
        title=f"REViGO plot of top non-redundant '{category}' GO terms for K. alvarezii protein predictions",
        height=600,
        width=900
    ).interactive()
    
    plot.save(f'output-plots/Revigo-PCA-{df["Subontology symbol"].values[0]}.html')
    plots.append(plot)

# alt.vconcat(plots[0], plots[1], plots[2])

# %%
plots[0]
# Out:
# alt.LayerChart(...)

# %%
plots[1]
# Out:
# alt.LayerChart(...)

# %%
plots[2]
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Treemap view

# %%
# Parse results
# stringent_results = "Revigo_Result.txt"
all_results = {
    "MF": "RevigoTreeMapMF.csv",
    "BP": "RevigoTreeMapBP.csv",
    "CC": "RevigoTreeMapCC.csv"
}
ontologies = {
    "MF": "Molecular function",
    "CC": "Cellular component",
    "BP": "Biological process"
}

for category, f in all_results.items():
    if not Path(f).exists():
        print(f"No file exists for {f}. \nPlease export treemap CSV data from http://revigo.irb.hr/Results.aspx.")
        

all_dfs = []
for category, f in all_results.items():       
    df = pd.read_csv(f, sep=",", skipinitialspace = True, quotechar='"', skiprows=[0,1,2,3])
    df["Subontology symbol"] = category
    df["Subontology"] = ontologies[category]
    all_dfs.append(df)

master_df = pd.concat(all_dfs)
master_df["Representative"].fillna("None", inplace=True)
master_df.head() # 124 rows before any filtering
# Out:
#        TermID                                            Name  Frequency  \
# 0  GO:0003777                      microtubule motor activity   0.186775
# 1  GO:0009976                     tocopherol cyclase activity   0.002332
# 2  GO:0016531                       copper chaperone activity   0.008897
# 3  GO:0017056          structural constituent of nuclear pore   0.065780
# 4  GO:0005458  GDP-mannose transmembrane transporter activity   0.004389
#
#    Value  Uniqueness  Dispensability                          Representative  \
# 0    NaN    0.980471        0.000000                                    None
# 1    NaN    0.966660        0.000000                                    None
# 2    NaN    0.993093        0.000000                                    None
# 3    NaN    0.967328        0.000000                                    None
# 4    NaN    0.956222        0.159301  structural constituent of nuclear pore
#
#   Subontology symbol         Subontology
# 0                 MF  Molecular function
# 1                 MF  Molecular function
# 2                 MF  Molecular function
# 3                 MF  Molecular function
# 4                 MF  Molecular function

# %%
plots = []
colors=['#fae588','#f79d65','#f9dc5c','#e8ac65','#e76f51','#ef233c','#b7094c'] #color palette

for category in master_df["Subontology"].unique():
    df = master_df[master_df["Subontology"] == category]
    
    fig = px.treemap(df, path=[
        px.Constant("all"), 
        'Representative', 
        'Name', 
        'TermID'  # note: leave this out to reduce information displayed on map (i.e. dont display the GO terms)
    ], values='Uniqueness')
    
    fig.update_layout(
        title={
            'text': f"Tree Map view of REViGO results for '{category}' GO terms",
            'y':0.98,
            'x':0.5,
            'xanchor': 'center',
            'yanchor': 'top'
        },
        treemapcolorway = colors, #defines the colors in the treemap
        margin = dict(t=50, l=25, r=25, b=25),
#         uniformtext=dict(minsize=10, mode='show'),
    )
    fig.update_traces(root_color="lightgrey")
    fig.write_html(f"output-plots/Revigo-treemap-{df['Subontology symbol'].values[0]}.html")

    plots.append(fig)

# %%
plots[0].show()
# Out:
# <div>                            <div id="c3e2ac07-2bb4-425b-8374-2aa51f336117" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3e2ac07-2bb4-425b-8374-2aa51f336117")) {                    Plotly.newPlot(                        "c3e2ac07-2bb4-425b-8374-2aa51f336117",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Uniqueness=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["all/geranylgeranyl reductase activity/prenylcysteine oxidase activity/GO:0001735","all/U6 snRNA binding/translation release factor activity/GO:0003747","all/None/microtubule motor activity/GO:0003777","all/molybdopterin synthase activity/alpha,alpha-trehalose-phosphate synthase (UDP-forming) activity/GO:0003825","all/phosphonoacetaldehyde hydrolase activity/1-alkyl-2-acetylglycerophosphocholine esterase activity/GO:0003847","all/molybdopterin synthase activity/6-phosphofructo-2-kinase activity/GO:0003873","all/molybdopterin synthase activity/ATP adenylyltransferase activity/GO:0003877","all/geranylgeranyl reductase activity/D-amino-acid oxidase activity/GO:0003884","all/geranylgeranyl reductase activity/D-arabinono-1,4-lactone oxidase activity/GO:0003885","all/geranylgeranyl reductase activity/N-acetyl-gamma-glutamyl-phosphate reductase activity/GO:0003942","all/molybdopterin synthase activity/NAD(P)+-protein-arginine ADP-ribosyltransferase activity/GO:0003956","all/molybdopterin syn
"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogra ...

# %%
plots[2].show()
# Out:
# <div>                            <div id="3efcdcc4-6110-4add-8bc6-edb9b499e6c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3efcdcc4-6110-4add-8bc6-edb9b499e6c9")) {                    Plotly.newPlot(                        "3efcdcc4-6110-4add-8bc6-edb9b499e6c9",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Uniqueness=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["all/None/microtubule/GO:0005874","all/None/plasma membrane/GO:0005886","all/microtubule/oligosaccharyltransferase complex/GO:0008250","all/microtubule/integral component of Golgi membrane/GO:0030173","all/MCM complex/small nuclear ribonucleoprotein complex/GO:0030532","all/MCM complex/BLOC-1 complex/GO:0031083","all/None/MCM complex/GO:0042555","all/MCM complex/BLOC-1 complex","all/None/MCM complex","all/microtubule/integral component of Golgi membrane","all/None/microtubule","all/microtubule/oligosaccharyltransferase complex","all/None/plasma membrane","all/MCM complex/small nuclear ribonucleoprotein complex","all/MCM complex","all/None","all/microtubule","all"],"labels":["GO:0005874","GO:0005886","GO:0008250","GO:0030173","GO:0030532","GO:0031083","GO:0042555","BLOC-1 complex","MCM complex","integral component of Golgi membrane","microtubule","oligosaccharyltransferase complex","plasma membrane","small nuclear ribonucleoprotein complex","MCM complex","None","microtubule","all"],"name":"","parents":["all/None/microtubule","all/None/plasma membrane","all/microtubule/oligosaccharyltransferase complex","all/microtubule/integral component of Golgi membrane","all/MCM complex/small nuclear ribonucleoprotein complex","all/MCM complex/BLOC-1 complex","all/None/MCM complex","all/MCM complex","all/None","all/microtubule","all/None","all/microtubule","all/None","all/MCM complex","all","all","all",""],"root":{"color":"lightgrey"},"type":"treemap","values":[0.743307611944267,0.980465972776413,0.602647357590838,0.720783016873817,0.571526896999077,0.638408624494431,0.736867388621876,0.638408624494431,0.736867388621876,0.720783016873817,0.743307611944267,0.602647357590838,0.980465972776413,0.571526896999077,1.2099355214935081,2.460640973342556,1.323430374464655,4.994006869300719]}],                        {"legend":{"tracegroupgap":0},"margin":{"b":25,"l":25,"r":25,"t":50},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[ ...

# %% [markdown]
# ### Sunburst view

# %%
plots = []
colors=['#fae588','#f79d65','#f9dc5c','#e8ac65','#e76f51','#ef233c','#b7094c'] #color palette

for category in master_df["Subontology"].unique():
    df = master_df[master_df["Subontology"] == category]
    
    fig = px.sunburst(df, path=[
        px.Constant("all"), 
        'Representative', 
        'Name', 
        'TermID'  
        # note: leave this out to reduce information displayed on map (i.e. dont display the GO terms)
        # maybe even make it toggle-able in the "app" somehow.        
    ], values='Uniqueness')
    
    fig.update_layout(
        title={
        'text': f"Sunburst view of REViGO results for '{category}' GO terms",
        'y':0.98,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'},
        treemapcolorway = colors, #defines the colors in the treemap
        margin = dict(t=50, l=25, r=25, b=25))
    fig.update_traces(root_color="lightgrey")
    fig.write_html(f"output-plots/Revigo-sunburst-{df['Subontology symbol'].values[0]}.html")
    
    plots.append(fig)

# %%
plots[0]
# Out:
# <div>                            <div id="0be93ab3-c518-4758-83d9-5a3d43f75873" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44932161-4389-4150-b5e4-431ee39111d9")) {                    Plotly.newPlot(                        "44932161-4389-4150-b5e4-431ee39111d9",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Uniqueness=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["all/None/transcription elongation from RNA polymerase II promoter/GO:0006368","all/None/transcription elongation from RNA polymerase II promoter","all/None","all"],"labels":["GO:0006368","transcription elongation from RNA polymerase II promoter","None","all"],"name":"","parents":["all/None/transcription elongation from RNA polymerase II promoter","all/None","all",""],"root":{"color":"lightgrey"},"type":"sunburst","values":[1.0,1.0,1.0,1.0]}],                        {"legend":{"tracegroupgap":0},"margin":{"b":25,"l":25,"r":25,"t":50},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogr ...

# %%
plots[2]
# Out:
# <div>                            <div id="2ae2ae80-f520-4b6c-8b1e-b02d33ef6d35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ae2ae80-f520-4b6c-8b1e-b02d33ef6d35")) {                    Plotly.newPlot(                        "2ae2ae80-f520-4b6c-8b1e-b02d33ef6d35",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Uniqueness=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["all/None/microtubule/GO:0005874","all/None/plasma membrane/GO:0005886","all/microtubule/oligosaccharyltransferase complex/GO:0008250","all/microtubule/integral component of Golgi membrane/GO:0030173","all/MCM complex/small nuclear ribonucleoprotein complex/GO:0030532","all/MCM complex/BLOC-1 complex/GO:0031083","all/None/MCM complex/GO:0042555","all/MCM complex/BLOC-1 complex","all/None/MCM complex","all/microtubule/integral component of Golgi membrane","all/None/microtubule","all/microtubule/oligosaccharyltransferase complex","all/None/plasma membrane","all/MCM complex/small nuclear ribonucleoprotein complex","all/MCM complex","all/None","all/microtubule","all"],"labels":["GO:0005874","GO:0005886","GO:0008250","GO:0030173","GO:0030532","GO:0031083","GO:0042555","BLOC-1 complex","MCM complex","integral component of Golgi membrane","microtubule","oligosaccharyltransferase complex","plasma membrane","small nuclear ribonucleoprotein complex","MCM complex","None","microtubule","all"],"name":"","parents":["all/None/microtubule","all/None/plasma membrane","all/microtubule/oligosaccharyltransferase complex","all/microtubule/integral component of Golgi membrane","all/MCM complex/small nuclear ribonucleoprotein complex","all/MCM complex/BLOC-1 complex","all/None/MCM complex","all/MCM complex","all/None","all/microtubule","all/None","all/microtubule","all/None","all/MCM complex","all","all","all",""],"root":{"color":"lightgrey"},"type":"sunburst","values":[0.743307611944267,0.980465972776413,0.602647357590838,0.720783016873817,0.571526896999077,0.638408624494431,0.736867388621876,0.638408624494431,0.736867388621876,0.720783016873817,0.743307611944267,0.602647357590838,0.980465972776413,0.571526896999077,1.2099355214935081,2.460640973342556,1.323430374464655,4.994006869300719]}],                        {"legend":{"tracegroupgap":0},"margin":{"b":25,"l":25,"r":25,"t":50},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"], ...

# %% [markdown]
# ---
